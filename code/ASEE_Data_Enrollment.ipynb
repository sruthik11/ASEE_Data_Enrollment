# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
query = pd.read_csv('../data/Census.csv', encoding = "ISO-8859-1")
# Out:
# /var/folders/z9/336qkncn48l4v8c1qftlly8r0000gn/T/ipykernel_67911/19457988.py:1: DtypeWarning: Columns (43,44,45,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   query = pd.read_csv('../data/Census.csv', encoding = "ISO-8859-1")

# %%
query
# Out:
#       ï»¿PERSON_ID          Last_Nm   First_Nm Middle_Nm  Term_CD  Report  \
# 0        100056448          Glovsky     Lowell         -     2237       1
# 1        100070104  Price-Broncucia        Teo         -     2237       1
# 2        100216213           Bailey    Charlie   Charles     2237       1
# 3        100217644            Akers       Cole      Cole     2237       1
# 4        100258108           Wagner      Kevin         -     2237       0
# ...            ...              ...        ...       ...      ...     ...
# 8687     830370533         Sullivan     Joseph         -     2237       1
# 8688     830374218         Barragan  Nathaniel         -     2237       1
# 8689     830382739             Rouw    Jannine      Vela     2237       1
# 8690     830387916           Nguyen     Ronald         -     2237       0
# 8691     995249535         Warriner     Austin   Douglas     2237       0
#
#       New NewType_Summer  Transfer  Grad  ...  Female  \
# 0       1              M         0     1  ...       0
# 1       0            NaN         0     1  ...       0
# 2       0            NaN         0     0  ...       0
# 3       0              T         1     0  ...       0
# 4       0            NaN         0     1  ...       0
# ...   ...            ...       ...   ...  ...     ...
# 8687    0            NaN         0     0  ...       0
# 8688    1              M         0     1  ...       0
# 8689    1              M         0     1  ...       1
# 8690    0            NaN         0     1  ...       0
# 8691    0            NaN         0     1  ...       0
#
#                                 EMail Identikey  TOT_Trnsfr  APHours IBHours  \
# 0         Lowell.Glovsky@colorado.edu  LOGL9514         0.0      NaN     NaN
# 1     Teo.Pricebroncucia@Colorado.EDU  TEPR6090         0.0      NaN     NaN
# 2               peba2926@Colorado.EDU  PEBA2926         0.0      NaN     NaN
# 3          William.Akers@Colorado.EDU  WIAK0179        33.0      0.0     0.0
# 4           Kevin.Wagner@colorado.edu  KEWA9233         0.0      NaN     NaN
# ...                               ...       ...         ...      ...     ...
# 8687     Joseph.Sullivan@Colorado.EDU  JOSU6651         6.0      0.0     0.0
# 8688  Nathaniel.Barragan@colorado.edu  NABA4632         0.0      NaN     NaN
# 8689        Jannine.Vela@Colorado.EDU  JAVE9878         0.0      NaN     NaN
# 8690       Ronald.Nguyen@Colorado.EDU  RONG9950         0.0      NaN     NaN
# 8691     Austin.Warriner@colorado.edu  AUWA4101         0.0      NaN     NaN
#
#       GoldShirt  Level_One Car_Req_Term_Cd IUT
# 0             0        NaN          2237.0   0
# 1             0        NaN          2177.0   0
# 2             0        NaN          2231.0   0
# 3             0        NaN          2217.0   0
# 4             0        NaN             NaN   0
# ...         ...        ...             ...  ..
# 8687          0        NaN          2117.0   0
# 8688          0        NaN          2237.0   0
# 8689          0        NaN          2237.0   0
# 8690          0        NaN             NaN   0
# 8691          0        NaN             NaN   0
#
# [8692 rows x 103 columns]

# %%
query.isna().sum()
# Out:
# ï»¿PERSON_ID          0
# Last_Nm               0
# First_Nm              0
# Middle_Nm             0
# Term_CD               0
#                    ...
# IBHours            3537
# GoldShirt             0
# Level_One          8692
# Car_Req_Term_Cd     260
# IUT                   0
# Length: 103, dtype: int64

# %%
query = query.rename(columns={'ï»¿PERSON_ID': 'PERSON_ID'})

# %%
query = query.loc[:, ['PERSON_ID', 'Last_Nm', 'First_Nm', 'Middle_Nm', 'Grad', 'SCD_FLPT', 'Class', 'Gender_CD', 'IPEDS_ETHNIC_GRP_CD', 'Major']]

# %%
query
# Out:
#       PERSON_ID          Last_Nm   First_Nm Middle_Nm  Grad SCD_FLPT Class  \
# 0     100056448          Glovsky     Lowell         -     1        F    GM
# 1     100070104  Price-Broncucia        Teo         -     1        F    GD
# 2     100216213           Bailey    Charlie   Charles     0        P   SR5
# 3     100217644            Akers       Cole      Cole     0        P   SR5
# 4     100258108           Wagner      Kevin         -     1        P    GM
# ...         ...              ...        ...       ...   ...      ...   ...
# 8687  830370533         Sullivan     Joseph         -     0        F   SR5
# 8688  830374218         Barragan  Nathaniel         -     1        P    GM
# 8689  830382739             Rouw    Jannine      Vela     1        F    GM
# 8690  830387916           Nguyen     Ronald         -     1        P    GM
# 8691  995249535         Warriner     Austin   Douglas     1        P    GM
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD Major
# 0            M               WHITE  MCEN
# 1            M               WHITE  CSEN
# 2            M               WHITE  CSAP
# 3            M               WHITE  CSAP
# 4            M               WHITE  ECE3
# ...        ...                 ...   ...
# 8687         M               WHITE  MCEN
# 8688         M               HISPA  ASEN
# 8689         F               HISPA  EMEN
# 8690         M               ASIAN  EME3
# 8691         M               WHITE  EME3
#
# [8692 rows x 10 columns]

# %%
query.isna().sum()
# Out:
# PERSON_ID              0
# Last_Nm                0
# First_Nm               0
# Middle_Nm              0
# Grad                   0
# SCD_FLPT               0
# Class                  0
# Gender_CD              0
# IPEDS_ETHNIC_GRP_CD    0
# Major                  0
# dtype: int64

# %%
df_filled = query.copy(deep=True)  # Create a copy of the dataframe to avoid modifying the original

# %%
df_filled
# Out:
#       PERSON_ID          Last_Nm   First_Nm Middle_Nm  Grad SCD_FLPT Class  \
# 0     100056448          Glovsky     Lowell         -     1        F    GM
# 1     100070104  Price-Broncucia        Teo         -     1        F    GD
# 2     100216213           Bailey    Charlie   Charles     0        P   SR5
# 3     100217644            Akers       Cole      Cole     0        P   SR5
# 4     100258108           Wagner      Kevin         -     1        P    GM
# ...         ...              ...        ...       ...   ...      ...   ...
# 8687  830370533         Sullivan     Joseph         -     0        F   SR5
# 8688  830374218         Barragan  Nathaniel         -     1        P    GM
# 8689  830382739             Rouw    Jannine      Vela     1        F    GM
# 8690  830387916           Nguyen     Ronald         -     1        P    GM
# 8691  995249535         Warriner     Austin   Douglas     1        P    GM
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD Major
# 0            M               WHITE  MCEN
# 1            M               WHITE  CSEN
# 2            M               WHITE  CSAP
# 3            M               WHITE  CSAP
# 4            M               WHITE  ECE3
# ...        ...                 ...   ...
# 8687         M               WHITE  MCEN
# 8688         M               HISPA  ASEN
# 8689         F               HISPA  EMEN
# 8690         M               ASIAN  EME3
# 8691         M               WHITE  EME3
#
# [8692 rows x 10 columns]

# %%
column_names = list(df_filled.columns[:])
column_names
# Out:
# ['PERSON_ID',
#  'Last_Nm',
#  'First_Nm',
#  'Middle_Nm',
#  'Grad',
#  'SCD_FLPT',
#  'Class',
#  'Gender_CD',
#  'IPEDS_ETHNIC_GRP_CD',
#  'Major']

# %% [markdown]
# ## Total Students

# %%
total = df_filled[column_names]

# %%
total
# Out:
#       PERSON_ID          Last_Nm   First_Nm Middle_Nm  Grad SCD_FLPT Class  \
# 0     100056448          Glovsky     Lowell         -     1        F    GM
# 1     100070104  Price-Broncucia        Teo         -     1        F    GD
# 2     100216213           Bailey    Charlie   Charles     0        P   SR5
# 3     100217644            Akers       Cole      Cole     0        P   SR5
# 4     100258108           Wagner      Kevin         -     1        P    GM
# ...         ...              ...        ...       ...   ...      ...   ...
# 8687  830370533         Sullivan     Joseph         -     0        F   SR5
# 8688  830374218         Barragan  Nathaniel         -     1        P    GM
# 8689  830382739             Rouw    Jannine      Vela     1        F    GM
# 8690  830387916           Nguyen     Ronald         -     1        P    GM
# 8691  995249535         Warriner     Austin   Douglas     1        P    GM
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD Major
# 0            M               WHITE  MCEN
# 1            M               WHITE  CSEN
# 2            M               WHITE  CSAP
# 3            M               WHITE  CSAP
# 4            M               WHITE  ECE3
# ...        ...                 ...   ...
# 8687         M               WHITE  MCEN
# 8688         M               HISPA  ASEN
# 8689         F               HISPA  EMEN
# 8690         M               ASIAN  EME3
# 8691         M               WHITE  EME3
#
# [8692 rows x 10 columns]

# %%
total_students = total.sum(axis=1)
# Out:
# /var/folders/z9/336qkncn48l4v8c1qftlly8r0000gn/T/ipykernel_67911/210360737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   total_students = total.sum(axis=1)

# %%
total_students
# Out:
# 0       100056449
# 1       100070105
# 2       100216213
# 3       100217644
# 4       100258109
#           ...
# 8687    830370533
# 8688    830374219
# 8689    830382740
# 8690    830387917
# 8691    995249536
# Length: 8692, dtype: int64

# %%
grad_tab = df_filled[df_filled['Grad'] == 1]

# %%
grad_tab
# Out:
#       PERSON_ID          Last_Nm   First_Nm Middle_Nm  Grad SCD_FLPT Class  \
# 0     100056448          Glovsky     Lowell         -     1        F    GM
# 1     100070104  Price-Broncucia        Teo         -     1        F    GD
# 4     100258108           Wagner      Kevin         -     1        P    GM
# 5     100286506             Rush       Gene    Robert     1        F    GD
# 6     100411000       Harrington      Amber   Patrice     1        P    GM
# ...         ...              ...        ...       ...   ...      ...   ...
# 8685  830369606             Bull         Ry         -     1        F    GD
# 8688  830374218         Barragan  Nathaniel         -     1        P    GM
# 8689  830382739             Rouw    Jannine      Vela     1        F    GM
# 8690  830387916           Nguyen     Ronald         -     1        P    GM
# 8691  995249535         Warriner     Austin   Douglas     1        P    GM
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD Major
# 0            M               WHITE  MCEN
# 1            M               WHITE  CSEN
# 4            M               WHITE  ECE3
# 5            M               ASIAN  MCEN
# 6            M               WHITE  EEEN
# ...        ...                 ...   ...
# 8685         M               WHITE  ASEN
# 8688         M               HISPA  ASEN
# 8689         F               HISPA  EMEN
# 8690         M               ASIAN  EME3
# 8691         M               WHITE  EME3
#
# [2575 rows x 10 columns]

# %%
undergrad_df = df_filled[df_filled['Grad'] == 0]

# %%
undergrad_df
# Out:
#       PERSON_ID    Last_Nm     First_Nm Middle_Nm  Grad SCD_FLPT Class  \
# 2     100216213     Bailey      Charlie   Charles     0        P   SR5
# 3     100217644      Akers         Cole      Cole     0        P   SR5
# 9     100461523     Nemeth        Vince    Arthur     0        P   SR5
# 10    100469134   Hastings         Ross         -     0        P   SR5
# 11    100496803      Porta  Jack Franck         -     0        F   SR5
# ...         ...        ...          ...       ...   ...      ...   ...
# 8679  830308790     Huerta       Sergio         -     0        F   SR5
# 8683  830333734   Ferzacca      JonPaul         -     0        P   SR5
# 8684  830344589      Weber         Nick         -     0        P   SR5
# 8686  830369710  Blackwood       Dallas         -     0        P   SR5
# 8687  830370533   Sullivan       Joseph         -     0        F   SR5
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD Major
# 2            M               WHITE  CSAP
# 3            M               WHITE  CSAP
# 9            M               WHITE  EEEN
# 10           M               WHITE  CSAP
# 11           M               HISPA  MCEN
# ...        ...                 ...   ...
# 8679         M               HISPA  CVEN
# 8683         M               HISPA  CSAP
# 8684         M               HISPA  CSAP
# 8686         M               HISPA  CSAP
# 8687         M               WHITE  MCEN
#
# [6117 rows x 10 columns]

# %%
freshman_tab = undergrad_df[undergrad_df["Class"]== "FR"]

# %%
freshman_tab
# Out:
#       PERSON_ID           Last_Nm    First_Nm  Middle_Nm  Grad SCD_FLPT Class  \
# 181   104322431           Johnson      Dustin     Joseph     0        F    FR
# 225   104731379     Vanim-Botting       Jerry          -     0        F    FR
# 309   105612891            Thomas        Kira          A     0        F    FR
# 389   106114266  Romero Hernandez      Daniel          -     0        F    FR
# 950   109001863            Kosacz         Ben       Jose     0        F    FR
# ...         ...               ...         ...        ...   ...      ...   ...
# 8481  111040428            Guerra  Maria Jose          -     0        F    FR
# 8500  111044922            Withee       Logan       Ares     0        F    FR
# 8512  111047460               Tan        Xuan          -     0        F    FR
# 8536  111058776             Klenz       Drake  Christian     0        F    FR
# 8563  111074529            Sexton     Michael    Richard     0        F    FR
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD Major
# 181          M               WHITE  CVEN
# 225          M               WHITE  EEEN
# 309          F               WHITE  IDEN
# 389          M               HISPA  MCEN
# 950          M               HISPA  CBEN
# ...        ...                 ...   ...
# 8481         F         NONRESALIEN  EVEN
# 8500         M               WHITE  MCEN
# 8512         M         NONRESALIEN  CSEN
# 8536         M               WHITE  ASEN
# 8563         M               HISPA  CSEN
#
# [919 rows x 10 columns]

# %%
entry_with_id_3 = freshman_tab[freshman_tab['PERSON_ID'] == 110299332]
print(entry_with_id_3)
# Out:
# Empty DataFrame
# Columns: [PERSON_ID, Last_Nm, First_Nm, Middle_Nm, Grad, SCD_FLPT, Class, Gender_CD, IPEDS_ETHNIC_GRP_CD, Major]
# Index: []

# %%
junior_tab = undergrad_df[undergrad_df["Class"]== "JR"]

# %%
junior_tab
# Out:
#       PERSON_ID    Last_Nm  First_Nm   Middle_Nm  Grad SCD_FLPT Class  \
# 24    101126800      Roman   Rosilio      Andres     0        F    JR
# 39    101415826   Hallberg    Joshua     Matthew     0        P    JR
# 45    101557687  Armstrong    Damian     Mi'chal     0        P    JR
# 119   103067633  Donaldson      Sean  Macfarland     0        F    JR
# 133   103283426    Belleau    Colton         Ray     0        F    JR
# ...         ...        ...       ...         ...   ...      ...   ...
# 8542  111060147      Jones     Mason           R     0        F    JR
# 8561  111074349   Hamilton      Nick        Paul     0        F    JR
# 8564  111074733    Matlack      Boaz      Shalom     0        F    JR
# 8567  111075246      Roman  Victoria           -     0        F    JR
# 8603  810008154   Chalmers       Cam           -     0        P    JR
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD    Major
# 24           M               HISPA     CSEN
# 39           M               HISPA  CSEN-BA
# 45           M               BLACK     ASEN
# 119          M               WHITE     MCEN
# 133          M               WHITE     ECEN
# ...        ...                 ...      ...
# 8542         M               WHITE     BMEN
# 8561         M               WHITE     ASEN
# 8564         M               BLACK     ASEN
# 8567         F               WHITE     BMEN
# 8603         M               WHITE     EEEN
#
# [1398 rows x 10 columns]

# %%
sophmore_tab = undergrad_df[undergrad_df["Class"]== "SO"]

# %%
sophmore_tab
# Out:
#       PERSON_ID    Last_Nm    First_Nm  Middle_Nm  Grad SCD_FLPT Class  \
# 220   104696534      Sharp        Sean          -     0        F    SO
# 349   105838143    Johnson       Tyler          B     0        F    SO
# 383   106087008      Sadow       Sadow          -     0        F    SO
# 498   107090385    Elliott        Sean          -     0        F    SO
# 538   107229216      Bacon        Zack          S     0        F    SO
# ...         ...        ...         ...        ...   ...      ...   ...
# 8549  111062895       Shim  Zanghyeoun          -     0        F    SO
# 8555  111068733  Sahatjian        Will          -     0        F    SO
# 8559  111073920      Riley      Thomas    Michael     0        F    SO
# 8562  111074352    Kishner        Theo  Nathaniel     0        F    SO
# 8599  111090909  Prochazka       Niall          -     0        F    SO
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD    Major
# 220          M               WHITE     ASEN
# 349          M               WHITE     MCEN
# 383          M               WHITE     ASEN
# 498          M               WHITE     ASEN
# 538          M               WHITE     ASEN
# ...        ...                 ...      ...
# 8549         M         NONRESALIEN     ECEN
# 8555         M               WHITE     ASEN
# 8559         M               WHITE  CSEN-BA
# 8562         M             UNKNOWN     ASEN
# 8599         M               WHITE     EPEN
#
# [1266 rows x 10 columns]

# %%
senior_tab = undergrad_df[(undergrad_df["Class"]== "SR") | (undergrad_df["Class"]== "SR5")]

# %%
senior_tab
# Out:
#       PERSON_ID    Last_Nm     First_Nm Middle_Nm  Grad SCD_FLPT Class  \
# 2     100216213     Bailey      Charlie   Charles     0        P   SR5
# 3     100217644      Akers         Cole      Cole     0        P   SR5
# 9     100461523     Nemeth        Vince    Arthur     0        P   SR5
# 10    100469134   Hastings         Ross         -     0        P   SR5
# 11    100496803      Porta  Jack Franck         -     0        F   SR5
# ...         ...        ...          ...       ...   ...      ...   ...
# 8679  830308790     Huerta       Sergio         -     0        F   SR5
# 8683  830333734   Ferzacca      JonPaul         -     0        P   SR5
# 8684  830344589      Weber         Nick         -     0        P   SR5
# 8686  830369710  Blackwood       Dallas         -     0        P   SR5
# 8687  830370533   Sullivan       Joseph         -     0        F   SR5
#
#      Gender_CD IPEDS_ETHNIC_GRP_CD Major
# 2            M               WHITE  CSAP
# 3            M               WHITE  CSAP
# 9            M               WHITE  EEEN
# 10           M               WHITE  CSAP
# 11           M               HISPA  MCEN
# ...        ...                 ...   ...
# 8679         M               HISPA  CVEN
# 8683         M               HISPA  CSAP
# 8684         M               HISPA  CSAP
# 8686         M               HISPA  CSAP
# 8687         M               WHITE  MCEN
#
# [2534 rows x 10 columns]

# %%
import pandas as pd

def filter_data(dataframe):
    # Filtering conditions
    major_mapping = {
        "ASEN": "1. Aerospace Engineering Sciences (B.S.)",
        "CBEN": "2. Chemical and Biological Engineering (B.S.)",
        "CHEN": "3. Chemical Engineering (B.S.)",
        "CSAP": "4. Applied Computer Science Post Bachelors (B.S.)",
        "CSEN": "5. Computer Science (B.S.)",
        "MCEN": "6. Mechanical Engineering (B.S.)",
        "TMEN": "7. Creative Technology and Design (B.S.)",
        "AMEN": "8. Applied Mathematics (B.S.)",
        "BMEN": "9. Biomedical Engineering (B.S.)",
        "EPEN": "10. Engineering Physics (B.S.)",
        "IDEN/GEEN": "11. Engineering Plus (B.S.)",
        "EVEN": "12. Environmental Engineering (B.S.)",
        "AREN": "13. Architectural Engineering (B.S.)",
        "CVEN": "14. Civil Engineering (B.S.)",
        "ECEN": "15. Electrical and Computer Engineering (B.S,)",
        "EEEN": "16. Electrical Engineering (B.S.)",
        "XXEN": "17. Open Option"
    }

    ethnicity_mapping = {
        "AMERIND": "1. American Indian",
        "ASIAN": "2. Asian",
        "BLACK": "3. Black",
        "HISPA": "4. Hispanic",
        "PACIF": "5. Pacific Islander",
        "WHITE": "6. White",
        "TWOPLUS": "7. Two or More",
        "NONRESALIEN": "8. Nonresident Alien",
        "UNKNOWN": "9. Unknown"
    }

    dataframe.loc[:, 'Major'] = dataframe['Major'].replace({'IDEN': 'IDEN/GEEN', 'GEEN': 'IDEN/GEEN'})
    # Create a DataFrame with all possible combinations of majors and ethnicity groups
    majors = list(major_mapping.keys())
    ethnicities = list(ethnicity_mapping.keys())
    all_combinations = pd.DataFrame([(major, ethnicity) for major in majors for ethnicity in ethnicities], columns=['Major', 'IPEDS_ETHNIC_GRP_CD'])

    # Merge the all_combinations DataFrame with the filtered DataFrame to ensure all majors are included
    merged_df = all_combinations.merge(dataframe, on=['Major', 'IPEDS_ETHNIC_GRP_CD'], how='left')
    merged_df.fillna(0, inplace=True)

    # Apply the conditions and group by major, ethnicity, gender, and student status
    filtered_df = merged_df.groupby(['Major', 'IPEDS_ETHNIC_GRP_CD', 'Gender_CD', 'SCD_FLPT']).size().reset_index(name='count')

    # Mapping
    filtered_df['Major'] = filtered_df['Major'].map(major_mapping)
    filtered_df['IPEDS_ETHNIC_GRP_CD'] = filtered_df['IPEDS_ETHNIC_GRP_CD'].map(ethnicity_mapping)

    # Pivot the DataFrame to create the desired format with new column names
    formatted_df = filtered_df.pivot(index=['Major', 'IPEDS_ETHNIC_GRP_CD'], columns=['SCD_FLPT', 'Gender_CD'], values='count')

    # Define the desired column order
    column_order = [
        ('F', 'M'), ('F', 'F'), ('P', 'M'), ('P', 'F')
    ]

    # Reorder the columns
    formatted_df = formatted_df[column_order]

    # Rename the columns to match the desired format
    formatted_df.columns = ['Full-Time Male', 'Full-Time Female', 'Part-Time Male', 'Part-Time Female']

    # Fill NaN values with 0
    formatted_df = formatted_df.fillna(0).astype(int)

    # Reset the index to keep "Major" and "IPEDS_ETHNIC_GRP_CD" as columns
    formatted_df.reset_index(inplace=True)

    formatted_df['Full-Time Total'] = formatted_df['Full-Time Male'] + formatted_df['Full-Time Female']
    formatted_df['Part-Time Total'] = formatted_df['Part-Time Male'] + formatted_df['Part-Time Female']
    formatted_df['Grand Total'] = formatted_df['Full-Time Total'] + formatted_df['Part-Time Total']

    # Reorder the columns to match the desired format
    formatted_df = formatted_df[['Major', 'IPEDS_ETHNIC_GRP_CD', 'Full-Time Male', 'Full-Time Female', 'Full-Time Total', 'Part-Time Male', 'Part-Time Female', 'Part-Time Total', 'Grand Total']]

    

    return formatted_df

def add_major_total_rows(dataframe):
    # Calculate the sum for each major
    major_total_rows = dataframe.groupby('Major').sum(numeric_only=True).reset_index()

    # Set the 'IPEDS_ETHNIC_GRP_CD' column in the total rows to 'Total'
    major_total_rows['IPEDS_ETHNIC_GRP_CD'] = 'Total'
    
    # Create a DataFrame to store the final result
    final_dataframe = pd.DataFrame(columns=dataframe.columns)
    
    # Iterate through majors and insert the total row for each major group
    for major in dataframe['Major'].unique():
        major_data = dataframe[dataframe['Major'] == major]
        major_total_data = major_total_rows[major_total_rows['Major'] == major]
        
        final_dataframe = pd.concat([final_dataframe, major_data, major_total_data], ignore_index=True)
    
    return final_dataframe

# %%
data_freshman_df = filter_data(freshman_tab)
freshman_df = add_major_total_rows(data_freshman_df)
# Out:
# /var/folders/z9/336qkncn48l4v8c1qftlly8r0000gn/T/ipykernel_67911/3925076761.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.loc[:, 'Major'] = dataframe['Major'].replace({'IDEN': 'IDEN/GEEN', 'GEEN': 'IDEN/GEEN'})

# %%
freshman_df
# Out:
#                                         Major   IPEDS_ETHNIC_GRP_CD  \
# 0    1. Aerospace Engineering Sciences (B.S.)    1. American Indian
# 1    1. Aerospace Engineering Sciences (B.S.)              2. Asian
# 2    1. Aerospace Engineering Sciences (B.S.)              3. Black
# 3    1. Aerospace Engineering Sciences (B.S.)           4. Hispanic
# 4    1. Aerospace Engineering Sciences (B.S.)   5. Pacific Islander
# ..                                        ...                   ...
# 165          9. Biomedical Engineering (B.S.)              6. White
# 166          9. Biomedical Engineering (B.S.)        7. Two or More
# 167          9. Biomedical Engineering (B.S.)  8. Nonresident Alien
# 168          9. Biomedical Engineering (B.S.)            9. Unknown
# 169          9. Biomedical Engineering (B.S.)                 Total
#
#     Full-Time Male Full-Time Female Full-Time Total Part-Time Male  \
# 0                0                0               0              0
# 1                7                2               9              0
# 2                1                2               3              0
# 3               14                9              23              0
# 4                0                1               1              0
# ..             ...              ...             ...            ...
# 165              9               22              31              0
# 166              3                8              11              0
# 167              1                4               5              0
# 168              0                0               0              0
# 169             19               51              70              0
#
#     Part-Time Female Part-Time Total Grand Total
# 0                  0               0           0
# 1                  0               0           9
# 2                  0               0           3
# 3                  0               0          23
# 4                  0               0           1
# ..               ...             ...         ...
# 165                0               0          31
# 166                0               0          11
# 167                0               0           5
# 168                0               0           0
# 169                0               0          70
#
# [170 rows x 9 columns]

# %%
freshman_df.to_csv('freshman_data.csv', index=False)

# %%
# Define a function to write each major's data to the file
def write_major_data(file, major, data):
    header = 'Major,Ethnicity,Full-Time Male, Full-Time Female, Full-Time Total, Part-Time Male, Part-Time Female, Part-Time Total, Grand Total\n'
    file.write(header)

    # Get unique major names
    major_names = data['Major'].unique()

    for major_name in major_names:
        major_data = data[data['Major'] == major_name]

        # Write the major name for each group of rows with the same major
        major_name_row = f'{major_name},,\n'
        file.write(major_name_row)

        # Remove the major name from the data and write the data
        data_without_major = major_data.copy()
        data_without_major['Major'] = ''
        data_without_major.to_csv(file, index=False, header=False, lineterminator='\n')

# Define a list of majors in the desired order
def custom_open(dataframe, csv_file_name):
    desired_major_order = [
    "1. Aerospace Engineering Sciences (B.S.)",
    "2. Chemical and Biological Engineering (B.S.)",
    "3. Chemical Engineering (B.S.)",
    "4. Applied Computer Science Post Bachelors (B.S.)",
    "5. Computer Science (B.S.)",
    "6. Mechanical Engineering (B.S.)",
    "7. Creative Technology and Design (B.S.)",
    "8. Applied Mathematics (B.S.)",
    "9. Biomedical Engineering (B.S.)",
    "10. Engineering Physics (B.S.)",
    "11. Engineering Plus (B.S.)",
    "12. Environmental Engineering (B.S.)",
    "13. Architectural Engineering (B.S.)",
    "14. Civil Engineering (B.S.)",
    "15. Electrical and Computer Engineering (B.S,)",
    "16. Electrical Engineering (B.S.)",
    "17. Open Option"
    ]

    # Save the DataFrame to a CSV file with custom formatting while maintaining the order
    with open(csv_file_name, 'w') as file:
        for major in desired_major_order:
            major_data = dataframe[dataframe['Major'] == major]
            if not major_data.empty:
                write_major_data(file, major, major_data)
                file.write('\n')  # Add an empty line to separate major sections

# %%
custom_open(freshman_df, 'freshman_data.csv')

# %%
data_sophomore_df = filter_data(sophmore_tab)
sophomore_df = add_major_total_rows(data_sophomore_df)
# Out:
# /var/folders/z9/336qkncn48l4v8c1qftlly8r0000gn/T/ipykernel_67911/3925076761.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.loc[:, 'Major'] = dataframe['Major'].replace({'IDEN': 'IDEN/GEEN', 'GEEN': 'IDEN/GEEN'})

# %%
sophomore_df
# Out:
#                                         Major   IPEDS_ETHNIC_GRP_CD  \
# 0    1. Aerospace Engineering Sciences (B.S.)    1. American Indian
# 1    1. Aerospace Engineering Sciences (B.S.)              2. Asian
# 2    1. Aerospace Engineering Sciences (B.S.)              3. Black
# 3    1. Aerospace Engineering Sciences (B.S.)           4. Hispanic
# 4    1. Aerospace Engineering Sciences (B.S.)   5. Pacific Islander
# ..                                        ...                   ...
# 165          9. Biomedical Engineering (B.S.)              6. White
# 166          9. Biomedical Engineering (B.S.)        7. Two or More
# 167          9. Biomedical Engineering (B.S.)  8. Nonresident Alien
# 168          9. Biomedical Engineering (B.S.)            9. Unknown
# 169          9. Biomedical Engineering (B.S.)                 Total
#
#     Full-Time Male Full-Time Female Full-Time Total Part-Time Male  \
# 0                1                0               1              0
# 1               17                9              26              0
# 2                1                2               3              0
# 3               25               10              35              3
# 4                0                0               0              0
# ..             ...              ...             ...            ...
# 165             14               30              44              2
# 166              1               10              11              0
# 167              0                1               1              0
# 168              0                0               0              0
# 169             20               51              71              2
#
#     Part-Time Female Part-Time Total Grand Total
# 0                  0               0           1
# 1                  0               0          26
# 2                  0               0           3
# 3                  0               3          38
# 4                  0               0           0
# ..               ...             ...         ...
# 165                0               2          46
# 166                0               0          11
# 167                0               0           1
# 168                0               0           0
# 169                0               2          73
#
# [170 rows x 9 columns]

# %%
sophomore_df.to_csv('sophomore_data.csv', index = False)

# %%
custom_open(sophomore_df, 'sophomore_data.csv')

# %%
data_junior_df = filter_data(junior_tab)
junior_df = add_major_total_rows(data_junior_df)
# Out:
# /var/folders/z9/336qkncn48l4v8c1qftlly8r0000gn/T/ipykernel_67911/3925076761.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.loc[:, 'Major'] = dataframe['Major'].replace({'IDEN': 'IDEN/GEEN', 'GEEN': 'IDEN/GEEN'})

# %%
junior_df
# Out:
#                                         Major   IPEDS_ETHNIC_GRP_CD  \
# 0    1. Aerospace Engineering Sciences (B.S.)    1. American Indian
# 1    1. Aerospace Engineering Sciences (B.S.)              2. Asian
# 2    1. Aerospace Engineering Sciences (B.S.)              3. Black
# 3    1. Aerospace Engineering Sciences (B.S.)           4. Hispanic
# 4    1. Aerospace Engineering Sciences (B.S.)   5. Pacific Islander
# ..                                        ...                   ...
# 165          9. Biomedical Engineering (B.S.)              6. White
# 166          9. Biomedical Engineering (B.S.)        7. Two or More
# 167          9. Biomedical Engineering (B.S.)  8. Nonresident Alien
# 168          9. Biomedical Engineering (B.S.)            9. Unknown
# 169          9. Biomedical Engineering (B.S.)                 Total
#
#     Full-Time Male Full-Time Female Full-Time Total Part-Time Male  \
# 0                0                0               0              0
# 1               13                2              15              1
# 2                2                2               4              1
# 3               19                8              27              0
# 4                0                0               0              0
# ..             ...              ...             ...            ...
# 165             16               23              39              0
# 166              5                1               6              0
# 167              0                0               0              0
# 168              0                0               0              0
# 169             32               36              68              0
#
#     Part-Time Female Part-Time Total Grand Total
# 0                  0               0           0
# 1                  0               1          16
# 2                  0               1           5
# 3                  0               0          27
# 4                  0               0           0
# ..               ...             ...         ...
# 165                0               0          39
# 166                0               0           6
# 167                0               0           0
# 168                0               0           0
# 169                0               0          68
#
# [170 rows x 9 columns]

# %%
junior_df.to_csv('junior_data.csv', index = False)

# %%
custom_open(junior_df, 'junior_data.csv')

# %%
data_senior_df = filter_data(senior_tab)
senior_df = add_major_total_rows(data_senior_df)
# Out:
# /var/folders/z9/336qkncn48l4v8c1qftlly8r0000gn/T/ipykernel_67911/3925076761.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.loc[:, 'Major'] = dataframe['Major'].replace({'IDEN': 'IDEN/GEEN', 'GEEN': 'IDEN/GEEN'})

# %%
senior_df
# Out:
#                                         Major   IPEDS_ETHNIC_GRP_CD  \
# 0    1. Aerospace Engineering Sciences (B.S.)    1. American Indian
# 1    1. Aerospace Engineering Sciences (B.S.)              2. Asian
# 2    1. Aerospace Engineering Sciences (B.S.)              3. Black
# 3    1. Aerospace Engineering Sciences (B.S.)           4. Hispanic
# 4    1. Aerospace Engineering Sciences (B.S.)   5. Pacific Islander
# ..                                        ...                   ...
# 165          9. Biomedical Engineering (B.S.)              6. White
# 166          9. Biomedical Engineering (B.S.)        7. Two or More
# 167          9. Biomedical Engineering (B.S.)  8. Nonresident Alien
# 168          9. Biomedical Engineering (B.S.)            9. Unknown
# 169          9. Biomedical Engineering (B.S.)                 Total
#
#     Full-Time Male Full-Time Female Full-Time Total Part-Time Male  \
# 0                1                0               1              0
# 1               25                9              34              7
# 2                0                0               0              1
# 3               39                9              48              5
# 4                0                0               0              0
# ..             ...              ...             ...            ...
# 165             23               39              62              2
# 166              5                5              10              2
# 167              1                1               2              0
# 168              0                0               0              0
# 169             41               66             107              4
#
#     Part-Time Female Part-Time Total Grand Total
# 0                  0               0           1
# 1                  1               8          42
# 2                  0               1           1
# 3                  2               7          55
# 4                  0               0           0
# ..               ...             ...         ...
# 165                1               3          65
# 166                1               3          13
# 167                0               0           2
# 168                0               0           0
# 169                2               6         113
#
# [170 rows x 9 columns]

# %%
custom_open(senior_df, 'senior_data.csv')

# %%
data_grad_df = filter_data(grad_tab)
grad_df = add_major_total_rows(data_grad_df)
# Out:
# /var/folders/z9/336qkncn48l4v8c1qftlly8r0000gn/T/ipykernel_67911/3925076761.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.loc[:, 'Major'] = dataframe['Major'].replace({'IDEN': 'IDEN/GEEN', 'GEEN': 'IDEN/GEEN'})

# %%
grad_df.to_csv('grad_data.csv', index = False)

# %%
custom_open(grad_df, 'grad_data.csv')

# %%
# import pandas as pd

# # List of CSV files to convert to sheets
# csv_files = ["freshman_data.csv", "sophomore_data.csv", "junior_data.csv", "senior_data.csv", "grad_data.csv"]

# # Output Excel file
# output_excel_file = "output.xlsx"

# # Create a Pandas Excel writer
# excel_writer = pd.ExcelWriter(output_excel_file, engine="xlsxwriter")

# # Loop through the CSV files and convert them to Excel sheets
# for csv_file in csv_files:
#     sheet_name = csv_file.split(".")[0]  # Use the CSV file name as the sheet name
#     df = pd.read_csv(csv_file)
#     df.to_excel(excel_writer, sheet_name=sheet_name, index=False)

# # Save the Excel file
# excel_writer.save()
# Out:
# /var/folders/z9/336qkncn48l4v8c1qftlly8r0000gn/T/ipykernel_67911/3686492099.py:19: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   excel_writer.save()

# %%
import pandas as pd
import xlsxwriter

# List of CSV files to convert to sheets
csv_files = ["freshman_data.csv", "sophomore_data.csv", "junior_data.csv", "senior_data.csv", "grad_data.csv"]

# Output Excel file
output_excel_file = "output.xlsx"

# Create a Pandas Excel writer with xlsxwriter engine
excel_writer = pd.ExcelWriter(output_excel_file, engine="xlsxwriter")

# Create a workbook and worksheet
workbook = excel_writer.book
bold_format = workbook.add_format({'bold': True})  # Create a bold formatting

# Loop through the CSV files and convert them to Excel sheets
for csv_file in csv_files:
    sheet_name = csv_file.split(".")[0]  # Use the CSV file name as the sheet name
    df = pd.read_csv(csv_file)

    # Create a worksheet with the sheet name
    worksheet = workbook.add_worksheet(sheet_name)

    # Write the data to the worksheet
    for row_num, data in enumerate(df.values):
        worksheet.write_row(row_num, 0, data, bold_format if row_num == 0 else None)

# Save the Excel file
excel_writer.save()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sruthi/Desktop/CUB_Grad School/On Campus/Data Analyst Job/ASEE_Data_Enrollment/code/ASEE_Data_Enrollment.ipynb Cell 51 line 2
#      <a href='vscode-notebook-cell:/Users/sruthi/Desktop/CUB_Grad%20School/On%20Campus/Data%20Analyst%20Job/ASEE_Data_Enrollment/code/ASEE_Data_Enrollment.ipynb#Y106sZmlsZQ%3D%3D?line=24'>25</a>     # Write the data to the worksheet
#      <a href='vscode-notebook-cell:/Users/sruthi/Desktop/CUB_Grad%20School/On%20Campus/Data%20Analyst%20Job/ASEE_Data_Enrollment/code/ASEE_Data_Enrollment.ipynb#Y106sZmlsZQ%3D%3D?line=25'>26</a>     for row_num, data in enumerate(df.values):
# ---> <a href='vscode-notebook-cell:/Users/sruthi/Desktop/CUB_Grad%20School/On%20Campus/Data%20Analyst%20Job/ASEE_Data_Enrollment/code/ASEE_Data_Enrollment.ipynb#Y106sZmlsZQ%3D%3D?line=26'>27</a>         worksheet.write_row(row_num, 0, data, bold_format if row_num == 0 else None)
#      <a href='vscode-notebook-cell:/Users/sruthi/Desktop/CUB_Grad%20School/On%20Campus/Data%20Analyst%20Job/ASEE_Data_Enrollment/code/ASEE_Data_Enrollment.ipynb#Y106sZmlsZQ%3D%3D?line=28'>29</a> # Save the Excel file
#      <a href='vscode-notebook-cell:/Users/sruthi/Desktop/CUB_Grad%20School/On%20Campus/Data%20Analyst%20Job/ASEE_Data_Enrollment/code/ASEE_Data_Enrollment.ipynb#Y106sZmlsZQ%3D%3D?line=29'>30</a> excel_writer.save()
#
# File ~/anaconda3/envs/testenv/lib/python3.10/site-packages/xlsxwriter/worksheet.py:110, in convert_cell_args.<locals>.cell_wrapper(self, *args, **kwargs)
#     107     new_args = xl_cell_to_rowcol(first_arg)
#     108     args = new_args + args[1:]
# --> 110 return method(self, *args, **kwargs)
#
# File ~/anaconda3/envs/testenv/lib/python3.10/site-packages/xlsxwriter/worksheet.py:1465, in Worksheet.write_row(self, row, col, data, cell_format)
#    1451 """
#    1452 Write a row of data starting from (row, col).
#    1453
#    (...)
#    1462
#    1463 """
#    1464 for token in data:
# -> 1465     error = self._write(row, col, token, cell_format)
#    1466     if error:
#    1467         return error
#
# File ~/anaconda3/envs/testenv/lib/python3.10/site-packages/xlsxwriter/worksheet.py:515, in Worksheet._write(self, row, col, *args)
#     512     return self._write_boolean(row, col, *args)
#     514 if token_type in (float, int, Decimal, Fraction):
# --> 515     return self._write_number(row, col, *args)
#     517 if token_type is str:
#     518     return self._write_token_as_string(token, row, col, *args)
#
# File ~/anaconda3/envs/testenv/lib/python3.10/site-packages/xlsxwriter/worksheet.py:638, in Worksheet._write_number(self, row, col, number, cell_format)
#     636             return self._write_formula(row, col, "-1/0", cell_format, "#DIV/0!")
#     637     else:
# --> 638         raise TypeError(
#     639             "NAN/INF not supported in write_number() "
#     640             "without 'nan_inf_to_errors' Workbook() option"
#     641         )
#     643 # Check that row and col are valid and store max and min values.
#     644 if self._check_dimensions(row, col):
#
# TypeError: NAN/INF not supported in write_number() without 'nan_inf_to_errors' Workbook() option

# %%
# import pandas as pd

# # List of CSV files to convert to sheets
# csv_files = ["freshman_data.csv", "sophmore_data.csv", "junior_data.csv", "senior_data.csv", "grad_data.csv"]

# # Output Excel file
# output_excel_file = "output.xlsx"

# # Create a Pandas Excel writer
# excel_writer = pd.ExcelWriter(output_excel_file, engine="xlsxwriter")

# # Initialize row and column counters
# start_row = 0
# start_col = 0

# # Loop through the CSV files and convert them to Excel sheets
# for csv_file in csv_files:
#     sheet_name = csv_file.split(".")[0]  # Use the CSV file name as the sheet name
#     df = pd.read_csv(csv_file)
    
#     # Write the DataFrame to the Excel sheet with start row and column
#     df.to_excel(excel_writer, sheet_name=sheet_name, index=False, startrow=start_row, startcol=start_col)
    
#     # Update start_row for the next sheet
#     start_row += len(df) + 2  # Add 2 for spacing between sheets

# # Save the Excel file
# excel_writer.save()

# %%
# import pandas as pd

# # List of CSV files to convert to sheets
# csv_files = ["freshman_data.csv", "sophomore_data.csv", "junior_data.csv", "senior_data.csv", "grad_data.csv"]

# # Output Excel file
# output_excel_file = "output.xlsx"

# # Create a Pandas Excel writer
# excel_writer = pd.ExcelWriter(output_excel_file, engine="xlsxwriter")

# # Define a function to check if a row matches the header format
# def is_header(row):
#     return row.str.contains(r'^\d+\.\s+[\w\s]+\t*$').any()

# # Loop through the CSV files and convert them to Excel sheets
# for csv_file in csv_files:
#     sheet_name = csv_file.split(".")[0]  # Use the CSV file name as the sheet name
#     df = pd.read_csv(csv_file)

#     header_found = False

#     for idx, row in df.iterrows():
#         if is_header(row):
#             if header_found:
#                 # Insert a blank row before the header, except for the first occurrence
#                 df = pd.concat([df.iloc[:idx], pd.Series(), df.iloc[idx:]]).reset_index(drop=True)
#             header_found = True

#     df.to_excel(excel_writer, sheet_name=sheet_name, index=False)

# # Close the Excel writer to save the file
# excel_writer.save()
